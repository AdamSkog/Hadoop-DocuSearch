# %%
import pyterrier as pt
if not pt.started():
  pt.init()
# Out:
# C:\Users\Fortu\AppData\Local\Temp\ipykernel_44008\1742394333.py:2: DeprecationWarning: Call to deprecated function (or staticmethod) started. (use pt.java.started() instead) -- Deprecated since version 0.11.0.
#   if not pt.started():
# Java started and loaded: pyterrier.java, pyterrier.terrier.java [version=5.10 (build: craigm 2024-08-22 17:33), helper_version=0.0.8]
# C:\Users\Fortu\AppData\Local\Temp\ipykernel_44008\1742394333.py:3: DeprecationWarning: Call to deprecated method pt.init(). Deprecated since version 0.11.0.
# java is now started automatically with default settings. To force initialisation early, run:
# pt.java.init() # optional, forces java initialisation
#   pt.init()

# %%
files = pt.io.find_files('c:/Users/Fortu/Downloads/SearchRec_FinalProject/apache.github.io')
indexer = pt.FilesIndexer('c:/Users/Fortu/Downloads/SearchRec_FinalProject/hadooptestindex',
                          verbose=True, blocks=False,
                          meta={"docno":20,"filename":1024,"title":1024},meta_tags={"title":"title"})
indexref = indexer.index(files)
index = pt.IndexFactory.of(indexref)
print(index.getCollectionStatistics().toString())
# Out:
# 18:02:50.982 [main] WARN org.terrier.indexing.SimpleFileCollection -- No available parser for file c:/Users/Fortu/Downloads/SearchRec_FinalProject/apache.github.io\hadoop\api\script.js, file is ignored.
# 18:02:50.988 [main] WARN org.terrier.structures.indexing.Indexer -- skipping null document
# 18:02:51.041 [main] WARN org.terrier.indexing.SimpleFileCollection -- No available parser for file c:/Users/Fortu/Downloads/SearchRec_FinalProject/apache.github.io\hadoop\api\stylesheet.css, file is ignored.
# 18:02:51.043 [main] WARN org.terrier.structures.indexing.Indexer -- skipping null document
# 18:02:51.055 [main] WARN org.terrier.indexing.SimpleFileCollection -- No available parser for file c:/Users/Fortu/Downloads/SearchRec_FinalProject/apache.github.io\hadoop\css\maven-base.css, file is ignored.
# 18:02:51.057 [main] WARN org.terrier.structures.indexing.Indexer -- skipping null document
# ...

# %%
import pandas as pd
queries = pd.DataFrame([["q1","speak"], ["q2","indulge"], ["q3", "swans"]], columns=["qid","query"])
queries
# Out:
#   qid    query
# 0  q1    speak
# 1  q2  indulge
# 2  q3    swans

# %%
# Similar script as assignment 4

index = pt.IndexFactory.of("c:/Users/Fortu/Downloads/SearchRec_FinalProject/hadooptestindex/data.properties")
BM = pt.BatchRetrieve(index, wmodel="BM25")
BM.transform(queries)
# Out:
# C:\Users\Fortu\AppData\Local\Temp\ipykernel_44008\767491211.py:4: DeprecationWarning: Call to deprecated class BatchRetrieve. (use pt.terrier.Retriever() instead) -- Deprecated since version 0.11.0.
#   BM = pt.BatchRetrieve(index, wmodel="BM25")
#   qid  docid  docno  rank      score  query
# 0  q1   1856  d1857     0  10.048371  speak
# 1  q1   1666  d1667     1   9.496451  speak

# %%
docid = 1856
document = index.getMetaIndex().getItem("filename", docid)
print(document)
# Out:
# c:/Users/Fortu/Downloads/SearchRec_FinalProject/apache.github.io\hadoop\api\org\apache\hadoop\mapreduce\lib\aggregate\ValueAggregatorJob.html
